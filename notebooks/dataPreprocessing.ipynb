# %%
import wfdb
import numpy as np

# %%
record_path = '/Users/priyanshusingh/Stevens-AAI-646/physionet.org/files/mitdb/1.0.0/100'

# %%
record = wfdb.rdrecord(record_path,sampto=5000)

# %%
wfdb.plot_wfdb(record=record)

# %%
annotation = wfdb.rdann(record_path,extension='atr',sampto=5000)

# %%
wfdb.plot_wfdb(record = record, annotation=annotation)

# %%
annotation.
